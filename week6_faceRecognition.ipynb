# %%
# %%cmd
# where python
# Out:
# Microsoft Windows [Version 10.0.22631.3880]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\Paridhi Mittal\Desktop\JN>where python
# C:\Users\Paridhi Mittal\AppData\Local\Programs\Python\Python310\python.exe
# C:\Users\Paridhi Mittal\AppData\Local\Microsoft\WindowsApps\python.exe
#
# C:\Users\Paridhi Mittal\Desktop\JN>

# %%
# !pip install face-recognition
# Out:
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached dlib-19.24.4.tar.gz (3.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# ...
# Failed to build dlib
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [13 lines of output]
#   running bdist_wheel
#   running build
#   running build_ext
#   Traceback (most recent call last):
# ...

# %%
# %%cmd
# pip install cmake
# Out:
# Microsoft Windows [Version 10.0.22631.3880]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\Paridhi Mittal\Desktop\JN>pip install cmake
# ...
#
# C:\Users\Paridhi Mittal\Desktop\JN>

# %%
# %%cmd
# pip install "C:\Users\Paridhi Mittal\Downloads\dlib-python whl packages\dlib-python whl packages\dlib-19.22.99-cp310-cp310-win_amd64.whl"
# Out:
# Microsoft Windows [Version 10.0.22631.3880]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\Paridhi Mittal\Desktop\JN>pip install "C:\Users\Paridhi Mittal\Downloads\dlib-python whl packages\dlib-python whl packages\dlib-19.22.99-cp310-cp310-win_amd64.whl"
# Processing c:\users\paridhi mittal\downloads\dlib-python whl packages\dlib-python whl packages\dlib-19.22.99-cp310-cp310-win_amd64.whl
# ...
#
# C:\Users\Paridhi Mittal\Desktop\JN>

# %%
# %%cmd
# pip install face-recognition
# Out:
# Microsoft Windows [Version 10.0.22631.3880]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\Paridhi Mittal\Desktop\JN>pip install face-recognition
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# ...
#
# C:\Users\Paridhi Mittal\Desktop\JN>

# %%
import cv2

# %%
img = cv2.imread("source code/Messi1.webp")

# %%
import face_recognition

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_encoding = face_recognition.face_encodings(rgb_img)[0]

# %%
img_encoding
# Out:
# array([-0.15317613,  0.1155012 ,  0.05193773, -0.02601075, -0.13780431,
#         0.12650488, -0.05446629, -0.06976613,  0.11499017, -0.07442608,
#         0.2490721 , -0.08307428, -0.30951083,  0.03118453, -0.06385998,
#         0.11342016, -0.13882959, -0.05114845, -0.11017055, -0.20850424,
#        -0.03290543,  0.09617091, -0.00319103, -0.00992197, -0.16317526,
#        -0.25847262, -0.00296268, -0.17273021,  0.06925581, -0.14343891,
#        -0.05158133,  0.0192033 , -0.08469331, -0.01187511,  0.05409322,
#         0.04483517, -0.00957706, -0.05857506,  0.23370828, -0.07038922,
#        -0.06249223,  0.00712138,  0.13706751,  0.27025723,  0.10487099,
#         0.01040111, -0.01161205, -0.10440052,  0.20039426, -0.22453687,
#         0.14081833,  0.13244259,  0.18262392,  0.10991331,  0.06287841,
#        -0.16909683, -0.05150935,  0.16557652, -0.16188961,  0.1110381 ,
#         0.11973467,  0.04621184, -0.09108631, -0.12560311,  0.25990644,
# ...

# %%
img2 = cv2.imread("source code/images/Elon Musk.jpg")

# %%
rgb_img2 = cv2.cvtColor(img2 , cv2.COLOR_BGR2RGB)
img2_encodings = face_recognition.face_encodings(rgb_img2)[0]

# %%
result = face_recognition.compare_faces([img_encoding], img2_encodings)
result
# Out:
# [False]

# %%
from simple_facerec import SimpleFacerec
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from simple_facerec import SimpleFacerec
#
# ModuleNotFoundError: No module named 'simple_facerec'

# %%
from face_recognition.simple_facerec import SimpleFacerec
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from face_recognition.simple_facerec import SimpleFacerec
#
# ModuleNotFoundError: No module named 'face_recognition.simple_facerec'

# %%
video = cv2.VideoCapture(0)

# %%
known_face_encodings=[]
known_face_names = []

# %%
image1 = cv2.imread("source code/images/Elon Musk.jpg")
image2  =cv2.imread("source code/images/Jeff Bezoz.jpg")
image3 = cv2.imread("source code/images/Messi.webp")
image4 = cv2.imread("source code/images/Paridhi Mittal.jpg")
image5 = cv2.imread("source code/images/Ryan Reynolds.jpg")

# %%
known_face_encodings.append(face_recognition.face_encodings(image1)[0])
known_face_encodings.append(face_recognition.face_encodings(image2)[0])
known_face_encodings.append(face_recognition.face_encodings(image3)[0])
known_face_encodings.append(face_recognition.face_encodings(image4)[0])
known_face_encodings.append(face_recognition.face_encodings(image5)[0])

# %%
known_face_names.append("ELon Musk")
known_face_names.append("Jeff Bezoz")
known_face_names.append("Messi")
known_face_names.append("Paridhi Mittal")
known_face_names.append("Ryan Reynolds")

# %%
video = cv2.VideoCapture(0)

while True:
    ret, frame = video.read()
    if not ret:
        print("Error: Unable to read frame from camera.")
        break

    face_locations = face_recognition.face_locations(frame)
    if len(face_locations) == 0:
        print("No faces detected in the frame.")
        continue

    face_encodings = face_recognition.face_encodings(frame, face_locations)
    for face_location, face_encoding in zip(face_locations, face_encodings):
        y1,x1,y2,x2 = face_location[0],face_location[1],face_location[2],face_location[3]
        matches = face_recognition.compare_faces(face_encoding , known_face_encodings)
        name = "Unknown"
        if True in matches:
            name_index = matches.index(True)
            name = known_face-names[name_index]
        cv2.rectangle(frame,(x1,y1),(x2,y2),(0,0,200),2)
        cv2.putText(frame,name, (x2,y1-10),cv2.FONT_HERSHEY_SIMPLEX,0.9,(0,0,255),2)

cv2.imshow("video", frame)
if cv2.WaitKey(1) & 0xFF == ord('q'):
    break

video.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 21
#      19 if True in matches:
#      20     name_index = matches.index(True)
# ---> 21     name = known_face-names[name_index]
#      22 cv2.rectangle(frame,(x1,y1),(x2,y2),(0,0,200),2)
#      23 cv2.putText(frame,name, (x2,y1-10),cv2.FONT_HERSHEY_SIMPLEX,0.9,(0,0,255),2)
#
# NameError: name 'known_face' is not defined

# %%
import cv2
import face_recognition

video = cv2.VideoCapture(0)
known_face_encodings = []
known_face_names = []

image1 = cv2.imread("source code/images/Elon Musk.jpg")
image2 = cv2.imread("source code/images/Jeff Bezoz.jpg")
image3 = cv2.imread("source code/images/Messi.webp")
image4 = cv2.imread("source code/images/Paridhi Mittal.jpg")
image5 = cv2.imread("source code/images/Ryan Reynolds.jpg")

known_face_encodings.append(face_recognition.face_encodings(image1)[0])
known_face_encodings.append(face_recognition.face_encodings(image2)[0])
known_face_encodings.append(face_recognition.face_encodings(image3)[0])
known_face_encodings.append(face_recognition.face_encodings(image4)[0])
known_face_encodings.append(face_recognition.face_encodings(image5)[0])

known_face_names.append("Elon Musk")
known_face_names.append("Jeff Bezoz")
known_face_names.append("Messi")
known_face_names.append("Paridhi Mittal")
known_face_names.append("Ryan Reynolds")

while True:
    ret, frame = video.read()
    if not ret:
        print("Error: Unable to read frame from camera.")
        break

    face_locations = face_recognition.face_locations(frame)
    if len(face_locations) == 0:
        print("No faces detected in the frame.")
        continue

    face_encodings = face_recognition.face_encodings(frame, face_locations)
    for face_location, face_encoding in zip(face_locations, face_encodings):
        y1,x1,y2,x2 = face_location[0],face_location[1],face_location[2],face_location[3]
        matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
        name = "Unknown"
        if True in matches:
            name_index = matches.index(True)
            name = known_face_names[name_index]
        cv2.rectangle(frame,(x1,y1),(x2,y2),(0,0,200),2)
        cv2.putText(frame,name, (x2,y1-10),cv2.FONT_HERSHEY_SIMPLEX,0.9,(0,0,255),2)

    cv2.imshow("video", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
# Out:
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# No faces detected in the frame.
# ...

# %%
m
